# %%
from keras import Input
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, Flatten, BatchNormalization, MaxPooling2D, concatenate, Conv2DTranspose

# %%
#create model
seq_model = Sequential()

#add model layers
seq_model.add(Conv2D(filters = 64, kernel_size=3, padding = 'same', activation='relu', input_shape=(256,256,20)))
seq_model.add(BatchNormalization())
seq_model.add(Conv2D(filters = 64, kernel_size=3, padding = 'same', activation='relu'))
seq_model.add(BatchNormalization())


input_tensor = Input(shape=(256,256,20,))
x = Conv2D(filters = 64, kernel_size=3, padding = 'same', activation='relu')(input_tensor)
x = BatchNormalization()(x)
x = Conv2D(filters = 64, kernel_size=3, padding = 'same', activation='relu')(x)
x = BatchNormalization()(x)

y = x

y = MaxPooling2D(strides = 2)(y)
y = Conv2D(filters = 128, kernel_size=3, padding = 'same', activation='relu')(y)
y = BatchNormalization()(y)
y = Conv2D(filters = 128, kernel_size=3, padding = 'same', activation='relu')(y)
y = BatchNormalization()(y)


z = y

z = MaxPooling2D(strides = 2)(z)
z = Conv2D(filters = 256, kernel_size=3, padding = 'same', activation='relu')(z)
z = BatchNormalization()(z)
z = Conv2D(filters = 256, kernel_size=3, padding = 'same', activation='relu')(z)
z = BatchNormalization()(z)


w = z

w = MaxPooling2D(strides = 2)(w)
w = Conv2D(filters = 512, kernel_size=3, padding = 'same', activation='relu')(w)
w = BatchNormalization()(w)
w = Conv2D(filters = 512, kernel_size=3, padding = 'same', activation='relu')(w)
w = BatchNormalization()(w)

u = w

u = MaxPooling2D(strides = 2)(u)
u = Conv2D(filters = 1024, kernel_size=3, padding = 'same', activation='relu')(u)
u = BatchNormalization()(u)
u = Conv2D(filters = 1024, kernel_size=3, padding = 'same', activation='relu')(u)
u = BatchNormalization()(u)
u = Conv2DTranspose(filters = 512, kernel_size = 1, strides = 2)(u)

v = concatenate([w, u])
v = Conv2D(filters = 512, kernel_size=3, padding = 'same', activation='relu')(v)
v = BatchNormalization()(v)
v = Conv2D(filters = 512, kernel_size=3, padding = 'same', activation='relu')(v)
v = BatchNormalization()(v)
v = Conv2DTranspose(filters = 256, kernel_size = 1, strides = 2)(v)


v = concatenate([z, v])
v = Conv2D(filters = 256, kernel_size=3, padding = 'same', activation='relu')(v)
v = BatchNormalization()(v)
v = Conv2D(filters = 256, kernel_size=3, padding = 'same', activation='relu')(v)
v = BatchNormalization()(v)
v = Conv2DTranspose(filters = 128, kernel_size = 1, strides = 2)(v)


v = concatenate([y, v])
v = Conv2D(filters = 128, kernel_size=3, padding = 'same', activation='relu')(v)
v = BatchNormalization()(v)
v = Conv2D(filters = 128, kernel_size=3, padding = 'same', activation='relu')(v)
v = BatchNormalization()(v)
v = Conv2DTranspose(filters = 64, kernel_size = 1, strides = 2)(v)


v = concatenate([x, v])
v = Conv2D(filters = 64, kernel_size=3, padding = 'same', activation='relu')(v)
v = BatchNormalization()(v)
v = Conv2D(filters = 64, kernel_size=3, padding = 'same', activation='relu')(v)
v = BatchNormalization()(v)
v = Conv2D(filters = 20, kernel_size = 1, strides = 1)(v)

model = Model(input_tensor, v)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_28 (InputLayer)           (None, 256, 256, 20) 0
# __________________________________________________________________________________________________
# conv2d_272 (Conv2D)             (None, 256, 256, 64) 11584       input_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_260 (BatchN (None, 256, 256, 64) 256         conv2d_272[0][0]
# __________________________________________________________________________________________________
# conv2d_273 (Conv2D)             (None, 256, 256, 64) 36928       batch_normalization_260[0][0]
# __________________________________________________________________________________________________
# batch_normalization_261 (BatchN (None, 256, 256, 64) 256         conv2d_273[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_67 (MaxPooling2D) (None, 128, 128, 64) 0           batch_normalization_261[0][0]
# __________________________________________________________________________________________________
# conv2d_274 (Conv2D)             (None, 128, 128, 128 73856       max_pooling2d_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_262 (BatchN (None, 128, 128, 128 512         conv2d_274[0][0]
# __________________________________________________________________________________________________
# conv2d_275 (Conv2D)             (None, 128, 128, 128 147584      batch_normalization_262[0][0]
# __________________________________________________________________________________________________
# batch_normalization_263 (BatchN (None, 128, 128, 128 512         conv2d_275[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_68 (MaxPooling2D) (None, 64, 64, 128)  0           batch_normalization_263[0][0]
# __________________________________________________________________________________________________
# conv2d_276 (Conv2D)             (None, 64, 64, 256)  295168      max_pooling2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_264 (BatchN (None, 64, 64, 256)  1024        conv2d_276[0][0]
# __________________________________________________________________________________________________
# conv2d_277 (Conv2D)             (None, 64, 64, 256)  590080      batch_normalization_264[0][0]
# __________________________________________________________________________________________________
# batch_normalization_265 (BatchN (None, 64, 64, 256)  1024        conv2d_277[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_69 (MaxPooling2D) (None, 32, 32, 256)  0           batch_normalization_265[0][0]
# __________________________________________________________________________________________________
# conv2d_278 (Conv2D)             (None, 32, 32, 512)  1180160     max_pooling2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_266 (BatchN (None, 32, 32, 512)  2048        conv2d_278[0][0]
# __________________________________________________________________________________________________
# conv2d_279 (Conv2D)             (None, 32, 32, 512)  2359808     batch_normalization_266[0][0]
# __________________________________________________________________________________________________
# batch_normalization_267 (BatchN (None, 32, 32, 512)  2048        conv2d_279[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_70 (MaxPooling2D) (None, 16, 16, 512)  0           batch_normalization_267[0][0]
# __________________________________________________________________________________________________
# conv2d_280 (Conv2D)             (None, 16, 16, 1024) 4719616     max_pooling2d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_268 (BatchN (None, 16, 16, 1024) 4096        conv2d_280[0][0]
# __________________________________________________________________________________________________
# conv2d_281 (Conv2D)             (None, 16, 16, 1024) 9438208     batch_normalization_268[0][0]
# __________________________________________________________________________________________________
# batch_normalization_269 (BatchN (None, 16, 16, 1024) 4096        conv2d_281[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_19 (Conv2DTran (None, 32, 32, 512)  524800      batch_normalization_269[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 32, 32, 1024) 0           batch_normalization_267[0][0]
#                                                                  conv2d_transpose_19[0][0]
# __________________________________________________________________________________________________
# conv2d_282 (Conv2D)             (None, 32, 32, 512)  4719104     concatenate_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_270 (BatchN (None, 32, 32, 512)  2048        conv2d_282[0][0]
# __________________________________________________________________________________________________
# conv2d_283 (Conv2D)             (None, 32, 32, 512)  2359808     batch_normalization_270[0][0]
# __________________________________________________________________________________________________
# batch_normalization_271 (BatchN (None, 32, 32, 512)  2048        conv2d_283[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_20 (Conv2DTran (None, 64, 64, 256)  131328      batch_normalization_271[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 64, 64, 512)  0           batch_normalization_265[0][0]
#                                                                  conv2d_transpose_20[0][0]
# __________________________________________________________________________________________________
# conv2d_284 (Conv2D)             (None, 64, 64, 256)  1179904     concatenate_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_272 (BatchN (None, 64, 64, 256)  1024        conv2d_284[0][0]
# __________________________________________________________________________________________________
# conv2d_285 (Conv2D)             (None, 64, 64, 256)  590080      batch_normalization_272[0][0]
# __________________________________________________________________________________________________
# batch_normalization_273 (BatchN (None, 64, 64, 256)  1024        conv2d_285[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_21 (Conv2DTran (None, 128, 128, 128 32896       batch_normalization_273[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 128, 128, 256 0           batch_normalization_263[0][0]
#                                                                  conv2d_transpose_21[0][0]
# __________________________________________________________________________________________________
# conv2d_286 (Conv2D)             (None, 128, 128, 128 295040      concatenate_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_274 (BatchN (None, 128, 128, 128 512         conv2d_286[0][0]
# __________________________________________________________________________________________________
# conv2d_287 (Conv2D)             (None, 128, 128, 128 147584      batch_normalization_274[0][0]
# __________________________________________________________________________________________________
# batch_normalization_275 (BatchN (None, 128, 128, 128 512         conv2d_287[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_22 (Conv2DTran (None, 256, 256, 64) 8256        batch_normalization_275[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 256, 256, 128 0           batch_normalization_261[0][0]
#                                                                  conv2d_transpose_22[0][0]
# __________________________________________________________________________________________________
# conv2d_288 (Conv2D)             (None, 256, 256, 64) 73792       concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_276 (BatchN (None, 256, 256, 64) 256         conv2d_288[0][0]
# __________________________________________________________________________________________________
# conv2d_289 (Conv2D)             (None, 256, 256, 64) 36928       batch_normalization_276[0][0]
# __________________________________________________________________________________________________
# batch_normalization_277 (BatchN (None, 256, 256, 64) 256         conv2d_289[0][0]
# __________________________________________________________________________________________________
# conv2d_290 (Conv2D)             (None, 256, 256, 20) 1300        batch_normalization_277[0][0]
# ==================================================================================================
# Total params: 28,977,364
# Trainable params: 28,965,588
# Non-trainable params: 11,776
# __________________________________________________________________________________________________
